# %%
#IMPORTs
import pandas as pd
import numpy as np
import matplotlib as plt
import re
from bs4 import BeautifulSoup
import json
import requests
from IPython.display import Image
import os

# %%
df = pd.read_csv("../OUTPUT/HDIrank2019_00_initialClean.csv")
df = df.drop(columns="Unnamed: 0")
df.head()
# Out:
#    HDIrank                Country    HDI  LifeExpectancy  \
# 0        1                 Norway  0.954            82.3
# 1        2            Switzerland  0.946            83.6
# 2        3                Ireland  0.942            82.1
# 3        4                Germany  0.939            81.2
# 4        5  Hong Kong China (SAR)  0.939            84.7
#
#    ExpectedSchoolingYears  MeanSchoolingYears  GNIperCapita  LastYearRank  \
# 0                    18.1                12.6         68059             1
# 1                    16.2                13.4         59375             2
# 2                    18.8                12.5         55660             3
# 3                    17.1                14.1         46946             4
# 4                    16.5                12.0         60221             6
#
#                       Category
# 0  VERY HIGH HUMAN DEVELOPMENT
# 1  VERY HIGH HUMAN DEVELOPMENT
# 2  VERY HIGH HUMAN DEVELOPMENT
# 3  VERY HIGH HUMAN DEVELOPMENT
# 4  VERY HIGH HUMAN DEVELOPMENT

# %%
def requestJSON(url):
    res = requests.get(url)
    if res.status_code != 200:
        print(res.text)
        raise ValueError("Bad Response")
    return res.json()

# %%
countries = requestJSON('https://restcountries.eu/rest/v2/all')

# %%
lista_name = [cm["name"] for cm in countries]
lista_name[:10]
# Out:
# ['Afghanistan',
#  'Åland Islands',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antarctica',
#  'Antigua and Barbuda']

# %%
def missedCountries():
    found=[]
    for ind,value in enumerate(df.Country):
        for elem in lista_name:
            if value == elem:
                found.append(ind)
    nofound=[]
    for i in range(189):
        if i not in found:
            nofound.append(i)
    noname=[]
    for i in nofound:
        noname.append(df.Country[i])
    
    return list(zip(nofound,noname))

# %%
nocountries = missedCountries()
nocountries
# Out:
# [(4, 'Hong Kong China (SAR)'),
#  (14, 'United Kingdom'),
#  (15, 'United States'),
#  (25, 'Czechia'),
#  (82, 'North Macedonia'),
#  (118, 'State of Palestine'),
#  (138, 'Eswatini (Kingdom of)'),
#  (158, 'Tanzania (United Republic of)')]

# %%
def countryMatch(regex,lst):
    chances=[]
    for i in lst:
        if re.match(f"{regex}",i):
            chances.append(i)
    return chances

# %%
countryMatch("\wong.+",lista_name)
# Out:
# ['Congo',
#  'Congo (Democratic Republic of the)',
#  'Hong Kong',
#  'Mongolia',
#  'Tonga']

# %% [markdown]
# Matching the list of missed country names using countryMatch function

# %%
lst = ['Hong Kong','United Kingdom of Great Britain and Northern Ireland','United States of America', 'Czech Republic','Macedonia (the former Yugoslav Republic of)','Palestine, State of','Swaziland','Tanzania, United Republic of']
for i in range(len(lst)):
    df = df.replace({'Country': nocountries[i]}, lst[i])

# %%
df.head(20)
# Out:
#     HDIrank                                            Country    HDI  \
# 0         1                                             Norway  0.954
# 1         2                                        Switzerland  0.946
# 2         3                                            Ireland  0.942
# 3         4                                            Germany  0.939
# 4         5                                          Hong Kong  0.939
# 5         6                                          Australia  0.938
# 6         7                                            Iceland  0.938
# 7         8                                             Sweden  0.937
# 8         9                                          Singapore  0.935
# 9        10                                        Netherlands  0.933
# 10       11                                            Denmark  0.930
# 11       12                                            Finland  0.925
# 12       13                                             Canada  0.922
# 13       14                                        New Zealand  0.921
# 14       15  United Kingdom of Great Britain and Northern I...  0.920
# 15       16                           United States of America  0.920
# 16       17                                            Belgium  0.919
# 17       18                                      Liechtenstein  0.917
# 18       19                                              Japan  0.915
# 19       20                                            Austria  0.914
#
#     LifeExpectancy  ExpectedSchoolingYears  MeanSchoolingYears  GNIperCapita  \
# 0             82.3                    18.1                12.6         68059
# 1             83.6                    16.2                13.4         59375
# 2             82.1                    18.8                12.5         55660
# 3             81.2                    17.1                14.1         46946
# 4             84.7                    16.5                12.0         60221
# 5             83.3                    22.1                12.7         44097
# 6             82.9                    19.2                12.5         47566
# 7             82.7                    18.8                12.4         47955
# 8             83.5                    16.3                11.5         83792
# 9             82.1                    18.0                12.2         50013
# 10            80.8                    19.1                12.6         48836
# 11            81.7                    19.3                12.4         41779
# 12            82.3                    16.1                13.3         43602
# 13            82.1                    18.8                12.7         35108
# 14            81.2                    17.4                13.0         39507
# 15            78.9                    16.3                13.4         56140
# 16            81.5                    19.7                11.8         43821
# 17            80.5                    14.7                12.5         99732
# 18            84.5                    15.2                12.8         40799
# 19            81.4                    16.3                12.6         46231
#
#     LastYearRank                     Category
# 0              1  VERY HIGH HUMAN DEVELOPMENT
# 1              2  VERY HIGH HUMAN DEVELOPMENT
# 2              3  VERY HIGH HUMAN DEVELOPMENT
# 3              4  VERY HIGH HUMAN DEVELOPMENT
# 4              6  VERY HIGH HUMAN DEVELOPMENT
# 5              5  VERY HIGH HUMAN DEVELOPMENT
# 6              7  VERY HIGH HUMAN DEVELOPMENT
# 7              7  VERY HIGH HUMAN DEVELOPMENT
# 8              9  VERY HIGH HUMAN DEVELOPMENT
# 9             10  VERY HIGH HUMAN DEVELOPMENT
# 10            11  VERY HIGH HUMAN DEVELOPMENT
# 11            12  VERY HIGH HUMAN DEVELOPMENT
# 12            13  VERY HIGH HUMAN DEVELOPMENT
# 13            14  VERY HIGH HUMAN DEVELOPMENT
# 14            15  VERY HIGH HUMAN DEVELOPMENT
# 15            15  VERY HIGH HUMAN DEVELOPMENT
# 16            17  VERY HIGH HUMAN DEVELOPMENT
# 17            18  VERY HIGH HUMAN DEVELOPMENT
# 18            19  VERY HIGH HUMAN DEVELOPMENT
# 19            20  VERY HIGH HUMAN DEVELOPMENT

# %%
now = missedCountries()
if len(now) == 0:
    print("No missed countries")
# Out:
# No missed countries

# %%
df.to_csv("../OUTPUT/HDIrank2019_01_countryNameClean.csv")

# %%
#Next step: Create the columns

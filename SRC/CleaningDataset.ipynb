# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../INPUT/HDI_country_ranking_2019.csv",sep=";")
df.head()
# Out:
#    HDI rank                Country    HDI LifeExpectancy  \
# 0         1                 Norway  0,954           82,3
# 1         2            Switzerland  0,946           83,6
# 2         3                Ireland  0,942           82,1
# 3         4                Germany  0,939           81,2
# 4         5  Hong Kong China (SAR)  0,939           84,7
#
#   ExpectedSchoolingYears MeanSchoolingYears  GNIperCapita  LastYearRank  \
# 0                   18,1               12,6        68.059             1
# 1                   16,2               13,4        59.375             2
# 2                   18,8               12,5        55.660             3
# 3                   17,1               14,1        46.946             4
# 4                   16,5               12,0        60.221             6
#
#                       Category
# 0  VERY HIGH HUMAN DEVELOPMENT
# 1  VERY HIGH HUMAN DEVELOPMENT
# 2  VERY HIGH HUMAN DEVELOPMENT
# 3  VERY HIGH HUMAN DEVELOPMENT
# 4  VERY HIGH HUMAN DEVELOPMENT

# %%
df.columns
# Out:
# Index(['HDI rank', 'Country', 'HDI', 'LifeExpectancy',
#        'ExpectedSchoolingYears', 'MeanSchoolingYears', 'GNIperCapita',
#        'LastYearRank', 'Category'],
#       dtype='object')

# %%
df = df.rename(columns={
                        "HDI rank":"HDIrank"
})

# %%
df.head()
# Out:
#    HDIrank                Country    HDI LifeExpectancy  \
# 0        1                 Norway  0,954           82,3
# 1        2            Switzerland  0,946           83,6
# 2        3                Ireland  0,942           82,1
# 3        4                Germany  0,939           81,2
# 4        5  Hong Kong China (SAR)  0,939           84,7
#
#   ExpectedSchoolingYears MeanSchoolingYears  GNIperCapita  LastYearRank  \
# 0                   18,1               12,6        68.059             1
# 1                   16,2               13,4        59.375             2
# 2                   18,8               12,5        55.660             3
# 3                   17,1               14,1        46.946             4
# 4                   16,5               12,0        60.221             6
#
#                       Category
# 0  VERY HIGH HUMAN DEVELOPMENT
# 1  VERY HIGH HUMAN DEVELOPMENT
# 2  VERY HIGH HUMAN DEVELOPMENT
# 3  VERY HIGH HUMAN DEVELOPMENT
# 4  VERY HIGH HUMAN DEVELOPMENT

# %%
df.dtypes
# Out:
# HDIrank                     int64
# Country                    object
# HDI                        object
# LifeExpectancy             object
# ExpectedSchoolingYears     object
# MeanSchoolingYears         object
# GNIperCapita              float64
# LastYearRank                int64
# Category                   object
# dtype: object

# %%
df.head()
# Out:
#    HDIrank                Country    HDI LifeExpectancy  \
# 0        1                 Norway  0,954           82,3
# 1        2            Switzerland  0,946           83,6
# 2        3                Ireland  0,942           82,1
# 3        4                Germany  0,939           81,2
# 4        5  Hong Kong China (SAR)  0,939           84,7
#
#   ExpectedSchoolingYears MeanSchoolingYears  GNIperCapita  LastYearRank  \
# 0                   18,1               12,6        68.059             1
# 1                   16,2               13,4        59.375             2
# 2                   18,8               12,5        55.660             3
# 3                   17,1               14,1        46.946             4
# 4                   16,5               12,0        60.221             6
#
#                       Category
# 0  VERY HIGH HUMAN DEVELOPMENT
# 1  VERY HIGH HUMAN DEVELOPMENT
# 2  VERY HIGH HUMAN DEVELOPMENT
# 3  VERY HIGH HUMAN DEVELOPMENT
# 4  VERY HIGH HUMAN DEVELOPMENT

# %%
#Replace "," by "." and make them float values.

numcol = ["HDI","LifeExpectancy","ExpectedSchoolingYears","MeanSchoolingYears"]
for i in numcol:
    df[i]=df[i].str.replace(',','.')
    df[i] = pd.to_numeric(df[i])

df.head()
# Out:
#    HDIrank                Country    HDI  LifeExpectancy  \
# 0        1                 Norway  0.954            82.3
# 1        2            Switzerland  0.946            83.6
# 2        3                Ireland  0.942            82.1
# 3        4                Germany  0.939            81.2
# 4        5  Hong Kong China (SAR)  0.939            84.7
#
#    ExpectedSchoolingYears  MeanSchoolingYears  GNIperCapita  LastYearRank  \
# 0                    18.1                12.6        68.059             1
# 1                    16.2                13.4        59.375             2
# 2                    18.8                12.5        55.660             3
# 3                    17.1                14.1        46.946             4
# 4                    16.5                12.0        60.221             6
#
#                       Category
# 0  VERY HIGH HUMAN DEVELOPMENT
# 1  VERY HIGH HUMAN DEVELOPMENT
# 2  VERY HIGH HUMAN DEVELOPMENT
# 3  VERY HIGH HUMAN DEVELOPMENT
# 4  VERY HIGH HUMAN DEVELOPMENT

# %%
df.dtypes
# Out:
# HDIrank                     int64
# Country                    object
# HDI                       float64
# LifeExpectancy            float64
# ExpectedSchoolingYears    float64
# MeanSchoolingYears        float64
# GNIperCapita              float64
# LastYearRank                int64
# Category                   object
# dtype: object

# %%
#Remove european thousand DOT from GNIperCapita
for i in df.GNIperCapita:
    if i > 100:
        df = df.replace({'GNIperCapita': i}, i/1000)
#Remove dot
df.GNIperCapita = df.GNIperCapita * 1000
#Cast
df = df.astype({'GNIperCapita': 'int32'})

# %%
df.head()
# Out:
#    HDIrank                Country    HDI  LifeExpectancy  \
# 0        1                 Norway  0.954            82.3
# 1        2            Switzerland  0.946            83.6
# 2        3                Ireland  0.942            82.1
# 3        4                Germany  0.939            81.2
# 4        5  Hong Kong China (SAR)  0.939            84.7
#
#    ExpectedSchoolingYears  MeanSchoolingYears  GNIperCapita  LastYearRank  \
# 0                    18.1                12.6         68059             1
# 1                    16.2                13.4         59375             2
# 2                    18.8                12.5         55660             3
# 3                    17.1                14.1         46946             4
# 4                    16.5                12.0         60221             6
#
#                       Category
# 0  VERY HIGH HUMAN DEVELOPMENT
# 1  VERY HIGH HUMAN DEVELOPMENT
# 2  VERY HIGH HUMAN DEVELOPMENT
# 3  VERY HIGH HUMAN DEVELOPMENT
# 4  VERY HIGH HUMAN DEVELOPMENT

# %%
for i in df['HDI']:
    if i < 1:
        df = df.replace({'HDI': i}, i*1000)

df.HDI = df.HDI/1000
df.HDI = df.HDI.round(3)
#Cast
df = df.astype({'HDIrank':'str', 'LastYearRank':'str'})
df.dtypes
# Out:
# HDIrank                    object
# Country                    object
# HDI                       float64
# LifeExpectancy            float64
# ExpectedSchoolingYears    float64
# MeanSchoolingYears        float64
# GNIperCapita                int32
# LastYearRank               object
# Category                   object
# dtype: object

# %%
df.head(20)
# Out:
#    HDIrank                Country    HDI  LifeExpectancy  \
# 0        1                 Norway  0.954            82.3
# 1        2            Switzerland  0.946            83.6
# 2        3                Ireland  0.942            82.1
# 3        4                Germany  0.939            81.2
# 4        5  Hong Kong China (SAR)  0.939            84.7
# 5        6              Australia  0.938            83.3
# 6        7                Iceland  0.938            82.9
# 7        8                 Sweden  0.937            82.7
# 8        9              Singapore  0.935            83.5
# 9       10            Netherlands  0.933            82.1
# 10      11                Denmark  0.930            80.8
# 11      12                Finland  0.925            81.7
# 12      13                 Canada  0.922            82.3
# 13      14            New Zealand  0.921            82.1
# 14      15         United Kingdom  0.920            81.2
# 15      16          United States  0.920            78.9
# 16      17                Belgium  0.919            81.5
# 17      18          Liechtenstein  0.917            80.5
# 18      19                  Japan  0.915            84.5
# 19      20                Austria  0.914            81.4
#
#     ExpectedSchoolingYears  MeanSchoolingYears  GNIperCapita LastYearRank  \
# 0                     18.1                12.6         68059            1
# 1                     16.2                13.4         59375            2
# 2                     18.8                12.5         55660            3
# 3                     17.1                14.1         46946            4
# 4                     16.5                12.0         60221            6
# 5                     22.1                12.7         44097            5
# 6                     19.2                12.5         47566            7
# 7                     18.8                12.4         47955            7
# 8                     16.3                11.5         83792            9
# 9                     18.0                12.2         50013           10
# 10                    19.1                12.6         48836           11
# 11                    19.3                12.4         41779           12
# 12                    16.1                13.3         43602           13
# 13                    18.8                12.7         35108           14
# 14                    17.4                13.0         39507           15
# 15                    16.3                13.4         56140           15
# 16                    19.7                11.8         43821           17
# 17                    14.7                12.5         99732           18
# 18                    15.2                12.8         40799           19
# 19                    16.3                12.6         46231           20
#
#                        Category
# 0   VERY HIGH HUMAN DEVELOPMENT
# 1   VERY HIGH HUMAN DEVELOPMENT
# 2   VERY HIGH HUMAN DEVELOPMENT
# 3   VERY HIGH HUMAN DEVELOPMENT
# 4   VERY HIGH HUMAN DEVELOPMENT
# 5   VERY HIGH HUMAN DEVELOPMENT
# 6   VERY HIGH HUMAN DEVELOPMENT
# 7   VERY HIGH HUMAN DEVELOPMENT
# 8   VERY HIGH HUMAN DEVELOPMENT
# 9   VERY HIGH HUMAN DEVELOPMENT
# 10  VERY HIGH HUMAN DEVELOPMENT
# 11  VERY HIGH HUMAN DEVELOPMENT
# 12  VERY HIGH HUMAN DEVELOPMENT
# 13  VERY HIGH HUMAN DEVELOPMENT
# 14  VERY HIGH HUMAN DEVELOPMENT
# 15  VERY HIGH HUMAN DEVELOPMENT
# 16  VERY HIGH HUMAN DEVELOPMENT
# 17  VERY HIGH HUMAN DEVELOPMENT
# 18  VERY HIGH HUMAN DEVELOPMENT
# 19  VERY HIGH HUMAN DEVELOPMENT

# %%
df.to_csv("../OUTPUT/HDIrank2019_00_initialclean.csv")
